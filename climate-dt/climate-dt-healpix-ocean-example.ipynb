# %% [markdown]
# ## Prerequisites
#
# ### Create a virtual environment with required packages
#
# You can follow the instructions in the README on how to create a conda environment that can run thsi notebook. You can then choose the kernel you created to run this notebook.
#
# ### Get the credentials to access polytope.
#
# You need to have an account on the [Destination Earth Platform](https://auth.destine.eu/realms/desp/account).
#
# Before running the notebook you need to set up your credentials. See the main readme of this repository for different ways to do this or use the following cells to authenticate.
#
# You will need to generate your credentials using the desp-authentication.py script.
#
# This can be run as follows:

# %%
# %%capture cap
# %run ../desp-authentication.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/Repos/MAINTAINED/polytope-examples/desp-authentication.py:9
#       7 import requests
#       8 from conflator import CLIArg, ConfigModel, Conflator, EnvVar
# ----> 9 from lxml import html
#      10 from pydantic import Field
#      12 IAM_URL = "https://auth.destine.eu"
#
# ModuleNotFoundError: No module named 'lxml'

# %% [markdown]
# This will generate a token that can then be used by earthkit and polytope.

# %%
output_1 = cap.stdout.split('}\n')
access_token = output_1[-1][0:-1]

# %% [markdown]
# The generated access tokens will be written to `~/.polytopeapirc`.

# %%
import xarray as xr
import numpy as np
import eccodes
import earthkit.data
import healpy as hp
import matplotlib.pylab as plt
import matplotlib.cm as cm
import cartopy.crs as ccrs
from polytope.api import Client

# %%
# Defaults to making a live data request. Set to false to use the cached GRIB file instead.
import os

LIVE_REQUEST = os.getenv("LIVE_REQUEST", "true").lower() == "true"
LIVE_REQUEST
# Out:
# True

# %%
request = {
        "class": "d1",
        "dataset": "climate-dt",
        "activity": "scenariomip",
        "experiment": "ssp3-7.0",
        "realization": "1",
        "generation" : "1",
        "model": "icon",
        "resolution": "high",
        "expver": "0001",
        "stream": "clte",
        "date": "20251129",
        "time": "0000",
        "type": "fc",
        "levelist" : "2",
        "levtype": "o3d",
        "param": "263501"
}

# %%
data_file = "data/climate-dt-healpix-ocean-example.grib"
if LIVE_REQUEST:
    data = earthkit.data.from_source("polytope", "destination-earth", request, address="polytope.lumi.apps.dte.destination-earth.eu", stream=False)
    data.to_target("file", data_file)
else:
    data = earthkit.data.from_source("file", data_file)
# Out:
# 2026-01-27 18:57:33 - INFO - Sending request...
# {'request': 'activity: scenariomip\n'
#             'class: d1\n'
#             'dataset: climate-dt\n'
#             "date: '20251129'\n"
#             'experiment: ssp3-7.0\n'
#             "expver: '0001'\n"
#             "generation: '1'\n"
#             "levelist: '2'\n"
#             'levtype: o3d\n'
#             'model: icon\n'
#             "param: '263501'\n"
#             "realization: '1'\n"
#             'resolution: high\n'
#             'stream: clte\n'
#             "time: '0000'\n"
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2026-01-27 18:57:34 - INFO - Request accepted. Please poll ./b87528c7-1f96-4b34-8182-27e9237c1fae for status
# 2026-01-27 18:57:34 - INFO - Checking request status (b87528c7-1f96-4b34-8182-27e9237c1fae)...
# 2026-01-27 18:57:35 - INFO - The current status of the request is 'queued'
# 2026-01-27 18:57:35 - INFO - The current status of the request is 'processing'
# 2026-01-27 18:57:37 - INFO - The current status of the request is 'processed'

# %%
dnp=data[0].values-273

hp.pixelfunc.get_map_size(dnp)
# Out:
# 12582912

# %%
interpolated_data = hp.cartview(dnp,
            flip="geo", 
            nest=True, 
            rot=[0,0,],
            unit='temperature',
            lonra=[-100,-30],
            latra=[20, 60],
            title='lev 2 pot-temperature over GS (ICON)',
            min=3,
            max=30,
            # notext=True
            cmap =cm.RdBu_r,
            badcolor='black',
            return_projected_map=True
           )
hp.graticule(dpar=10, dmer=10)

# %%
request2 = {
        "class": "d1",
        "dataset": "climate-dt",
        "activity": "scenariomip",
        "experiment": "ssp3-7.0",
        "realization": "1",
        "generation" : "1",
        "model": "ifs-nemo",
        "resolution": "high",
        "expver": "0001",
        "stream": "clte",
        "date": "20251129",
        "time": "0000",
        "type": "fc",
        "levelist" : "2",
        "levtype": "o3d",
        "param": "263501"
    }

# %%
data_file2 = "data/climate-dt-healpix-ocean-example2.grib"
if LIVE_REQUEST:
    data2 = earthkit.data.from_source("polytope", "destination-earth", request2, address="polytope.lumi.apps.dte.destination-earth.eu", stream=False)
    data2.to_target("file", data_file2)
else:
    data2 = earthkit.data.from_source("file", data_file2)
# Out:
# 2026-01-27 18:57:40 - INFO - Sending request...
# {'request': 'activity: scenariomip\n'
#             'class: d1\n'
#             'dataset: climate-dt\n'
#             "date: '20251129'\n"
#             'experiment: ssp3-7.0\n'
#             "expver: '0001'\n"
#             "generation: '1'\n"
#             "levelist: '2'\n"
#             'levtype: o3d\n'
#             'model: ifs-nemo\n'
#             "param: '263501'\n"
#             "realization: '1'\n"
#             'resolution: high\n'
#             'stream: clte\n'
#             "time: '0000'\n"
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2026-01-27 18:57:41 - INFO - Request accepted. Please poll ./dfe487f8-a25d-4103-8fec-32d6734cf390 for status
# 2026-01-27 18:57:41 - INFO - Checking request status (dfe487f8-a25d-4103-8fec-32d6734cf390)...
# 2026-01-27 18:57:41 - INFO - The current status of the request is 'queued'
# 2026-01-27 18:57:42 - INFO - The current status of the request is 'processing'
# 2026-01-27 18:57:44 - INFO - The current status of the request is 'processed'
# Recovering from connection error [HTTPSConnectionPool(host='download-polytope.lumi.apps.dte.destination-earth.eu', port=443): Read timed out. (read timeout=30)], attempt 1 of 500
# Retrying in 120 seconds

# %%
dnp2=data2[0].values-273

interpolated_data = hp.cartview(dnp2,
            flip="geo", 
            nest=True, 
            rot=[0,0,],
            unit='temperature',
            lonra=[-100,-30],
            latra=[20, 60],
            title='lev 2 pot-temperature over GS (IFS)',
            min=3,
            max=30,
            # notext=True
            cmap =cm.RdBu_r,
            badcolor='black',
            return_projected_map=True
           )
hp.graticule(dpar=10, dmer=10)
