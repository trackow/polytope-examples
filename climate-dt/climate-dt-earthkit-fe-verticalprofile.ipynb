# %% [markdown]
# ## Polytope Climate-DT Feature Extraction Vertical Profile example notebook
#
# This notebook shows how to use earthkit-data and earthkit-plots to pull destination-earth data from LUMI and plot it using earthkit-plots.
#
#
# Before running the notebook you need to set up your credentials. See the main readme of this repository for different ways to do this or use the following cells to authenticate.
#
# You will need to generate your credentials using the desp-authentication.py script.
#
# This can be run as follows:

# %%
# %%capture cap
# %run ../desp-authentication.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/Repos/MAINTAINED/polytope-examples/desp-authentication.py:9
#       7 import requests
#       8 from conflator import CLIArg, ConfigModel, Conflator, EnvVar
# ----> 9 from lxml import html
#      10 from pydantic import Field
#      12 IAM_URL = "https://auth.destine.eu"
#
# ModuleNotFoundError: No module named 'lxml'

# %% [markdown]
# This will generate a token that can then be used by earthkit and polytope.

# %%
output_1 = cap.stdout.split('}\n')
access_token = output_1[-1][0:-1]

# %% [markdown]
# # Requirements
# To run this notebook install the following:
# * pip install earthkit-data
# * pip install earthkit-plots
# * pip install cf-units         (Optional for unit conversion in maps)

# %%
import earthkit.data
import earthkit.regrid
from earthkit.plots.interactive import Chart
from polytope.api import Client

# %%
# Defaults to making a live data request. Set to false to use the cached GRIB file instead.
import os

LIVE_REQUEST = os.getenv("LIVE_REQUEST", "true").lower() == "true"
LIVE_REQUEST
# Out:
# True

# %%
request = {
        "activity": "scenariomip",
        "class": "d1",
        "dataset": "climate-dt",
        "experiment": "ssp3-7.0",
        "generation": "1",
        "levtype": "pl",
        "date": "20210101",
        "model": "ifs-nemo",
        "expver": "0001",
        "param": "131",
        "realization": "1",
        "resolution": "high",
        "stream": "clte",
        "type": "fc",
        "time": "0000",
        "levelist": "1/to/1000",
        "feature": {
            "type": "verticalprofile",
            "points": [[38.9, -9.1]],
        },
    }

# %%
data_file = "data/climate-dt-earthkit-fe-verticalprofile.covjson"
if LIVE_REQUEST:
    data = earthkit.data.from_source("polytope", "destination-earth", request, address="polytope.lumi.apps.dte.destination-earth.eu", stream=False)
    data.to_target("file", data_file)
else:
    data = earthkit.data.from_source("file", data_file)
# Out:
# 2026-01-27 18:52:41 - INFO - Sending request...
# {'request': 'activity: scenariomip\n'
#             'class: d1\n'
#             'dataset: climate-dt\n'
#             "date: '20210101'\n"
#             'experiment: ssp3-7.0\n'
#             "expver: '0001'\n"
#             'feature:\n'
#             '  points:\n'
#             '  - - 38.9\n'
#             '    - -9.1\n'
#             '  type: verticalprofile\n'
#             "generation: '1'\n"
#             'levelist: 1/to/1000\n'
#             'levtype: pl\n'
#             'model: ifs-nemo\n'
#             "param: '131'\n"
#             "realization: '1'\n"
#             'resolution: high\n'
#             'stream: clte\n'
#             "time: '0000'\n"
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2026-01-27 18:52:42 - INFO - Request accepted. Please poll ./25f6f78d-25b1-465a-9ab4-36f04e4b1d41 for status
# 2026-01-27 18:52:42 - INFO - Checking request status (25f6f78d-25b1-465a-9ab4-36f04e4b1d41)...
# 2026-01-27 18:52:42 - INFO - The current status of the request is 'processing'
# 2026-01-27 18:52:47 - INFO - The current status of the request is 'processed'

# %%
# Convert data to xarray
da = data.to_xarray()

# %%
da
# Out:
# <xarray.Dataset> Size: 416B
# Dimensions:    (latitude: 1, longitude: 1, number: 1, datetime: 1, time: 1,
#                 levelist: 19)
# Coordinates:
#   * latitude   (latitude) float64 8B 38.87
#   * longitude  (longitude) float64 8B 350.9
#   * number     (number) int64 8B 0
#   * datetime   (datetime) <U20 80B '2021-01-01T00:00:00Z'
#   * time       (time) int64 8B 0
#   * levelist   (levelist) int64 152B 1 5 10 20 30 50 ... 600 700 850 925 1000
# Data variables:
#     u          (latitude, longitude, number, datetime, time, levelist) float64 152B ...
# Attributes: (12/15)
#     activity:       scenariomip
#     class:          d1
#     dataset:        climate-dt
#     Forecast date:  2021-01-01T00:00:00Z
#     experiment:     ssp3-7.0
#     expver:         0001
#     ...             ...
#     model:          ifs-nemo
#     realization:    1
#     resolution:     high
#     stream:         clte
#     type:           fc
#     number:         0

# %%
chart = Chart()
fig = chart.fig
fig['layout']['yaxis']['autorange'] = "reversed"
chart.line(da, y="levelist")
chart.fig.update_layout(yaxis={"title": "hPa"})
chart.title("Vertical profile over Lisbon from the DestinE's Climate DT")
chart.show("png") # Replace with chart.show() in an interactive session!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 fig = chart.fig
#       3 fig['layout']['yaxis']['autorange'] = "reversed"
# ----> 4 chart.line(da, y="levelist")
#       5 chart.fig.update_layout(yaxis={"title": "hPa"})
#       6 chart.title("Vertical profile over Lisbon from the DestinE's Climate DT")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/earthkit_0_13_2/lib/python3.12/site-packages/earthkit/plots/interactive/charts.py:108, in Chart.set_subplot_titles.<locals>.wrapper(self, *args, **kwargs)
#     106             else:
#     107                 self._subplot_y_titles = titles
# --> 108 return method(self, *args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/earthkit_0_13_2/lib/python3.12/site-packages/earthkit/plots/interactive/charts.py:172, in Chart.line(self, *args, **kwargs)
#     153 @set_subplot_titles
#     154 def line(self, *args, **kwargs):
#     155     """
#     156     Adds a line plot to the chart.
#     157
#    (...)    170     Titles are inferred from data attributes if not provided.
#     171     """
# --> 172     traces = line.line(*args, **kwargs)
#     173     for i, trace in enumerate(traces):
#     174         if isinstance(trace, list):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/earthkit_0_13_2/lib/python3.12/site-packages/earthkit/plots/interactive/inputs.py:106, in sanitise.<locals>.decorator.<locals>.wrapper(data, time_frequency, time_aggregation, aggregation, deaccumulate, *args, **kwargs)
#     104         traces.append(function(*args, **trace_kwargs))
#     105 else:
# --> 106     trace_kwargs = get_xarray_kwargs(ds, axes, kwargs)
#     107     if not multiplot:
#     108         if time_axis is None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/earthkit_0_13_2/lib/python3.12/site-packages/earthkit/plots/interactive/inputs.py:151, in get_xarray_kwargs(data, axes, kwargs)
#     149 else:
#     150     attr = attr.split(".")[-1]
# --> 151     if attr in axis_attrs.values() + assigned_attrs:
#     152         attr = data_vars[0]
#     153         if len(data_vars) > 1:
#
# TypeError: unsupported operand type(s) for +: 'dict_values' and 'list'
