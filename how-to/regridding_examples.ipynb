# %% [markdown]
# Server side regridding with Polytope

# %%
import earthkit.data

# %%
request_original = {
        "class": "d1",
        "expver": "0001",
        "stream": "oper",
        "dataset": "extremes-dt",
        "date": "-14",
        "time": "0000",
        "type": "fc",
        "levtype": "sfc",
        "step": "0",
        "param": "167",
        "grid": "av" #retrieve original archived grid
    }
original_grid = earthkit.data.from_source("polytope", "destination-earth", request_original, address="polytope.lumi.apps.dte.destination-earth.eu", stream=False)
# Out:
# 2025-09-29 11:07:55 - INFO - Key read from /Users/maes/.polytopeapirc
# 2025-09-29 11:07:55 - INFO - Sending request...
# {'request': 'class: d1\n'
#             'dataset: extremes-dt\n'
#             "date: '-14'\n"
#             "expver: '0001'\n"
#             'grid: av\n'
#             'levtype: sfc\n'
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: oper\n'
#             "time: '0000'\n"
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2025-09-29 11:07:55 - INFO - Polytope user key found in session cache for user maes
# 2025-09-29 11:07:57 - INFO - Request accepted. Please poll ./d73eb525-43df-4020-bd31-e514a8ce7de4 for status
# 2025-09-29 11:07:57 - INFO - Polytope user key found in session cache for user maes
# 2025-09-29 11:07:57 - INFO - Checking request status (d73eb525-43df-4020-bd31-e514a8ce7de4)...
# 2025-09-29 11:07:57 - INFO - The current status of the request is 'queued'
# 2025-09-29 11:07:58 - INFO - The current status of the request is 'processing'
# 2025-09-29 11:08:02 - INFO - The current status of the request is 'processed'

# %%
original_grid.ls() # display original grid, in this case it will be reduced_gg
# Out:
#   centre shortName        typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf        2t  heightAboveGround      2  20250915         0         0
#
#   dataType number    gridType
# 0       fc   None  reduced_gg

# %% [markdown]
# Lat/Lon Regriding

# %%
request_lat_lon = {
        "class": "d1",
        "expver": "0001",
        "stream": "oper",
        "dataset": "extremes-dt",
        "date": "-14",
        "time": "0000",
        "type": "fc",
        "levtype": "sfc",
        "step": "0",
        "param": "167",
        "grid": "0.1/0.1" #lon/lat value
    }
lat_lon_grid = earthkit.data.from_source("polytope", "destination-earth", request_lat_lon, address="polytope.lumi.apps.dte.destination-earth.eu", stream=False)
# Out:
# 2025-09-29 11:08:12 - INFO - Key read from /Users/maes/.polytopeapirc
# 2025-09-29 11:08:12 - INFO - Sending request...
# {'request': 'class: d1\n'
#             'dataset: extremes-dt\n'
#             "date: '-14'\n"
#             "expver: '0001'\n"
#             'grid: 0.1/0.1\n'
#             'levtype: sfc\n'
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: oper\n'
#             "time: '0000'\n"
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2025-09-29 11:08:12 - INFO - Polytope user key found in session cache for user maes
# 2025-09-29 11:08:13 - INFO - Request accepted. Please poll ./eb26bd73-b042-48e7-a2b0-97924473824c for status
# 2025-09-29 11:08:13 - INFO - Polytope user key found in session cache for user maes
# 2025-09-29 11:08:13 - INFO - Checking request status (eb26bd73-b042-48e7-a2b0-97924473824c)...
# 2025-09-29 11:08:13 - INFO - The current status of the request is 'queued'
# 2025-09-29 11:08:14 - INFO - The current status of the request is 'processing'
# 2025-09-29 11:08:22 - INFO - The current status of the request is 'processed'

# %%
lat_lon_grid.ls() # grid now in lat/lon
# Out:
#   centre shortName        typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf        2t  heightAboveGround      2  20250915         0         0
#
#   dataType number    gridType
# 0       fc   None  regular_ll

# %%
request_healpix = {
        "class": "d1",
        "expver": "0001",
        "stream": "oper",
        "dataset": "extremes-dt",
        "date": "-14",
        "time": "0000",
        "type": "fc",
        "levtype": "sfc",
        "step": "0",
        "param": "167",
        "grid": "H512"
    }
healpix_grid = earthkit.data.from_source("polytope", "destination-earth", request_healpix, address="polytope.lumi.apps.dte.destination-earth.eu", stream=False)
# Out:
# 2025-09-29 11:08:25 - INFO - Key read from /Users/maes/.polytopeapirc
# 2025-09-29 11:08:25 - INFO - Sending request...
# {'request': 'class: d1\n'
#             'dataset: extremes-dt\n'
#             "date: '-14'\n"
#             "expver: '0001'\n"
#             'grid: H512\n'
#             'levtype: sfc\n'
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: oper\n'
#             "time: '0000'\n"
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2025-09-29 11:08:25 - INFO - Polytope user key found in session cache for user maes
# 2025-09-29 11:08:26 - INFO - Request accepted. Please poll ./6949f28b-fcc4-4e13-9d89-d7ee09a89f1a for status
# 2025-09-29 11:08:26 - INFO - Polytope user key found in session cache for user maes
# 2025-09-29 11:08:26 - INFO - Checking request status (6949f28b-fcc4-4e13-9d89-d7ee09a89f1a)...
# 2025-09-29 11:08:26 - INFO - The current status of the request is 'queued'
# 2025-09-29 11:08:28 - INFO - The current status of the request is 'processing'
# 2025-09-29 11:09:32 - INFO - The current status of the request is 'processed'

# %%
healpix_grid.ls() # healpix
# Out:
#   centre shortName        typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf        2t  heightAboveGround      2  20250915         0         0
#
#   dataType number gridType
# 0       fc   None  healpix

# %% [markdown]
# Client side regridding with Earthkit Data

# %%
import earthkit.regrid

# %%
request = {
    'activity': 'ScenarioMIP',
    'class': 'd1',
    'dataset': 'climate-dt',
    'date': '20200102',
    'experiment': 'SSP3-7.0',
    'expver': '0001',
    'generation': '1',
    'levtype': 'sfc',
    'model': 'IFS-NEMO',
    'param': '134',
    'realization': '1',
    'resolution': 'standard',
    'stream': 'clte',
    'time': '0100', # '0100/0200/0300/0400/0500/0600'
    'type': 'fc'
}

# %%
data = earthkit.data.from_source("polytope", "destination-earth", request, address="polytope.lumi.apps.dte.destination-earth.eu", stream=False)
# Out:
# 2025-09-29 11:09:34 - INFO - Key read from /Users/maes/.polytopeapirc
# 2025-09-29 11:09:34 - INFO - Sending request...
# {'request': 'activity: ScenarioMIP\n'
#             'class: d1\n'
#             'dataset: climate-dt\n'
#             "date: '20200102'\n"
#             'experiment: SSP3-7.0\n'
#             "expver: '0001'\n"
#             "generation: '1'\n"
#             'levtype: sfc\n'
#             'model: IFS-NEMO\n'
#             "param: '134'\n"
#             "realization: '1'\n"
#             'resolution: standard\n'
#             'stream: clte\n'
#             "time: '0100'\n"
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2025-09-29 11:09:34 - INFO - Polytope user key found in session cache for user maes
# 2025-09-29 11:09:35 - INFO - Request accepted. Please poll ./9127cb87-2341-490b-9bef-53d7e8079657 for status
# 2025-09-29 11:09:35 - INFO - Polytope user key found in session cache for user maes
# 2025-09-29 11:09:35 - INFO - Checking request status (9127cb87-2341-490b-9bef-53d7e8079657)...
# 2025-09-29 11:09:36 - INFO - The current status of the request is 'queued'
# 2025-09-29 11:09:38 - INFO - The current status of the request is 'processing'
# 2025-09-29 11:09:40 - INFO - The current status of the request is 'processed'

# %%
data.ls() # healpix grid
# Out:
#   centre shortName typeOfLevel  level  dataDate  dataTime stepRange dataType  \
# 0   ecmf        sp     surface      0  20200102       100         0       fc
#
#   number gridType
# 0   None  healpix

# %%
# regrid to 1x1 degree
out_grid = {"grid": [1,1]}
data_interpolated = earthkit.regrid.interpolate(data, out_grid=out_grid, method="linear")

# %%
data_interpolated.ls() # now on regular lat lon grid
# Out:
#   centre shortName typeOfLevel  level  dataDate  dataTime stepRange dataType  \
# 0   ecmf        sp     surface      0  20200102       100         0       fc
#
#   number    gridType
# 0   None  regular_ll

# %%
import earthkit.data

request_original = {
        "class": "d1",
        "expver": "0001",
        "stream": "oper",
        "dataset": "extremes-dt",
        "date": "-14",
        "time": "0000",
        "type": "fc",
        "levtype": "sfc",
        "step": "13",
        "param": "167",
        # "feature" : {
        # "type" : "boundingbox",
        # "points" : [[30, -15], [75, 42]],
        # "axes" : ["latitude", "longitude"]
        # },
        "area": "75/-15/30/42.5",
        "grid": "0.01/0.01"
    }
original_grid = earthkit.data.from_source("polytope", "destination-earth", request_original, address="polytope.lumi.apps.dte.destination-earth.eu", stream=False)
# Out:
# 2025-09-29 11:09:41 - INFO - Key read from /Users/maes/.polytopeapirc
# 2025-09-29 11:09:41 - INFO - Sending request...
# {'request': 'area: 75/-15/30/42.5\n'
#             'class: d1\n'
#             'dataset: extremes-dt\n'
#             "date: '-14'\n"
#             "expver: '0001'\n"
#             'grid: 0.01/0.01\n'
#             'levtype: sfc\n'
#             "param: '167'\n"
#             "step: '13'\n"
#             'stream: oper\n'
#             "time: '0000'\n"
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2025-09-29 11:09:41 - INFO - Polytope user key found in session cache for user maes
# 2025-09-29 11:09:42 - INFO - Request accepted. Please poll ./2304f4bb-80fd-47b8-9289-2862621589e6 for status
# 2025-09-29 11:09:42 - INFO - Polytope user key found in session cache for user maes
# 2025-09-29 11:09:43 - INFO - Checking request status (2304f4bb-80fd-47b8-9289-2862621589e6)...
# 2025-09-29 11:09:43 - INFO - The current status of the request is 'queued'
# 2025-09-29 11:09:45 - INFO - The current status of the request is 'processing'
# 2025-09-29 11:12:04 - INFO - The current status of the request is 'processed'

# %%
original_grid.ls()
# Out:
#   centre shortName        typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf        2t  heightAboveGround      2  20250915         0        13
#
#   dataType number    gridType
# 0       fc   None  regular_ll

# %%
chart = earthkit.plots.Map()
chart.grid_cells(
    original_grid[0],
    auto_style=True,
)

# chart.title("Temerature at 2m")
chart.coastlines()
chart.gridlines()
chart.show()
# Out:
# ECCODES WARNING :  Key gridSpec is not yet implemented. Work in progress...
